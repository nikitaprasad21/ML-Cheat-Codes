# %% [markdown]
# # CSV (Comma-Separated Values)
#
# Q. What is CSV?
# - CSV is a simple and widely used file format for storing tabular data (data in rows and columns).
# Each line of the file represents a row, and the values within a row are separated by commas.
#
# ![image.png](attachment:image.png)
#
# Q. Advantages of CSV:
# * Simplicity: Easy to understand and work with.
# * Compatibility: Can be opened and edited in various spreadsheet programs.
# * Interoperability: Supported by many data analysis and machine learning tools.

# %% [markdown]
# # CSV Cheatcodes 2024
#
# Let's discuss, how to use pandas to `read_csv` function's various parameters while working with `csv` or `tsv` files.
#
# Note: This cheat code serves as a reference for addressing any challenges encountered with CSV or TSV files in the future.

# %% [markdown]
# ### Importing pandas

# %%
# Import the pandas library and alias it as pd
import pandas as pd

# %% [markdown]
# ### 1. Opening a CSV file present locally on system or in same folder
#
# `file_path`: Represents the path to the CSV or TSV file.

# %%
# Read a CSV file named 'new_employee.csv' into a pandas DataFrame
data = pd.read_csv("new_employee.csv")

# Display the DataFrame
data.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0
# 3              52     1.0
# 4               8     0.0

# %% [markdown]
# ### 2.Using the 'index_col' parameter
#
# `index_col`: This is to allow you to set which columns to be used as the index of the dataframe.
#
# Note: `index_col` is optional, and if it's not specified, the DataFrame will have the default `integer index`. If you don't have a specific column to use as the index, you can omit this parameter.

# %%
# Read 'new_employee.csv' and set the 'enrollee_id' column as the index
pd.read_csv('new_employee.csv', index_col='enrollee_id')
# Out:
#                  city  city_development_index  gender  \
# enrollee_id
# 8949         city_103                   0.920    Male
# 29725         city_40                   0.776    Male
# 11561         city_21                   0.624     NaN
# 33241        city_115                   0.789     NaN
# 666          city_162                   0.767    Male
# 21651        city_176                   0.764     NaN
# 28806        city_160                   0.920    Male
# 402           city_46                   0.762    Male
# 27107        city_103                   0.920    Male
# 699          city_103                   0.920     NaN
# 29452         city_21                   0.624     NaN
# 23853        city_103                   0.920    Male
# 25619         city_61                   0.913    Male
# 5826          city_21                   0.624    Male
# 8722          city_21                   0.624     NaN
# 6588         city_114                   0.926    Male
# 4167         city_103                   0.920     NaN
# 5764          city_21                   0.624     NaN
# 2156          city_21                   0.624     NaN
# 11399         city_13                   0.827  Female
# 31972        city_159                   0.843    Male
# 19061        city_114                   0.926    Male
# 6491         city_102                   0.804     NaN
# 7041          city_40                   0.776    Male
# 22767         city_21                   0.624     NaN
# 14505         city_67                   0.855     NaN
# 17139         city_21                   0.624     NaN
# 28476        city_103                   0.920    Male
# 21538        city_100                   0.887    Male
# 10408         city_21                   0.624    Male
# 14928        city_103                   0.920    Male
# 22293        city_103                   0.920    Male
# 4324         city_103                   0.920  Female
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 8949         Has relevent experience       no_enrollment        Graduate
# 29725         No relevent experience       no_enrollment        Graduate
# 11561         No relevent experience    Full time course        Graduate
# 33241         No relevent experience                 NaN        Graduate
# 666          Has relevent experience       no_enrollment         Masters
# 21651        Has relevent experience    Part time course        Graduate
# 28806        Has relevent experience       no_enrollment     High School
# 402          Has relevent experience       no_enrollment        Graduate
# 27107        Has relevent experience       no_enrollment        Graduate
# 699          Has relevent experience       no_enrollment        Graduate
# 29452         No relevent experience    Full time course     High School
# 23853        Has relevent experience       no_enrollment        Graduate
# 25619        Has relevent experience       no_enrollment        Graduate
# 5826          No relevent experience                 NaN             NaN
# 8722          No relevent experience    Full time course     High School
# 6588         Has relevent experience       no_enrollment        Graduate
# 4167         Has relevent experience       no_enrollment        Graduate
# 5764         Has relevent experience       no_enrollment        Graduate
# 2156         Has relevent experience       no_enrollment        Graduate
# 11399        Has relevent experience       no_enrollment        Graduate
# 31972        Has relevent experience       no_enrollment         Masters
# 19061        Has relevent experience       no_enrollment         Masters
# 6491         Has relevent experience       no_enrollment         Masters
# 7041         Has relevent experience       no_enrollment        Graduate
# 22767        Has relevent experience       no_enrollment        Graduate
# 14505         No relevent experience       no_enrollment     High School
# 17139        Has relevent experience    Part time course        Graduate
# 28476        Has relevent experience       no_enrollment        Graduate
# 21538        Has relevent experience       no_enrollment     High School
# 10408        Has relevent experience       no_enrollment        Graduate
# 14928        Has relevent experience       no_enrollment        Graduate
# 22293        Has relevent experience    Part time course        Graduate
# 4324          No relevent experience    Full time course        Graduate
#
#             major_discipline experience company_size    company_type  \
# enrollee_id
# 8949                    STEM        >20          NaN             NaN
# 29725                   STEM         15        50-99         Pvt Ltd
# 11561                   STEM          5          NaN             NaN
# 33241        Business Degree         <1          NaN         Pvt Ltd
# 666                     STEM        >20        50-99  Funded Startup
# 21651                   STEM         11          NaN             NaN
# 28806                    NaN          5        50-99  Funded Startup
# 402                     STEM         13          <10         Pvt Ltd
# 27107                   STEM          7        50-99         Pvt Ltd
# 699                     STEM         17       10000+         Pvt Ltd
# 29452                    NaN          2          NaN             NaN
# 23853                   STEM          5    5000-9999         Pvt Ltd
# 25619                   STEM        >20    1000-4999         Pvt Ltd
# 5826                     NaN          2          NaN             NaN
# 8722                     NaN          5          NaN             NaN
# 6588                    STEM         16        10/49         Pvt Ltd
# 4167                    STEM          1        50-99         Pvt Ltd
# 5764                    STEM          2    5000-9999         Pvt Ltd
# 2156                    STEM          7       10000+         Pvt Ltd
# 11399                   Arts          4          NaN             NaN
# 31972                   STEM         11      100-500         Pvt Ltd
# 19061                   STEM         11      100-500         Pvt Ltd
# 6491                    STEM         10          NaN             NaN
# 7041              Humanities         <1    1000-4999         Pvt Ltd
# 22767                   STEM          5    1000-4999         Pvt Ltd
# 14505                    NaN          4          NaN             NaN
# 17139                   STEM         14      500-999         Pvt Ltd
# 28476                   Arts          5          NaN             NaN
# 21538                    NaN         11          <10         Pvt Ltd
# 10408                   STEM         18        50-99  Funded Startup
# 14928                   STEM        >20      100-500         Pvt Ltd
# 22293                   STEM         19    5000-9999         Pvt Ltd
# 4324                    STEM          5          NaN             NaN
#
#             last_new_job  training_hours  target
# enrollee_id
# 8949                   1              36     1.0
# 29725                 >4              47     0.0
# 11561              never              83     0.0
# 33241              never              52     1.0
# 666                    4               8     0.0
# 21651                  1              24     1.0
# 28806                  1              24     0.0
# 402                   >4              18     1.0
# 27107                  1              46     1.0
# 699                   >4             123     0.0
# 29452              never              32     1.0
# 23853                  1             108     0.0
# 25619                  3              23     0.0
# 5826               never              24     0.0
# 8722               never              26     0.0
# 6588                  >4              18     0.0
# 4167               never             106     0.0
# 5764                   2               7     0.0
# 2156               never              23     1.0
# 11399                  1             132     1.0
# 31972                  1              68     0.0
# 19061                  2              50     0.0
# 6491                   1              48     0.0
# 7041                   1              65     0.0
# 22767                  1              13     0.0
# 14505              never              22     0.0
# 17139                  1             148     1.0
# 28476                  2              72     0.0
# 21538                  1               8     1.0
# 10408                  2              68     1.0
# 14928                  3              40     0.0
# 22293                 >4             141     0.0
# 4324                   1              24     0.0

# %% [markdown]
# ### 3.Using the 'usecols' parameter
#
# `usecols`: Specifies a subset of columns to be read from the file.

# %%
# Read 'new_employee.csv' and select only specific columns
pd.read_csv("new_employee.csv", usecols= ["enrollee_id", "relevent_experience",	"experience", "last_new_job"])
# Out:
#     enrollee_id      relevent_experience experience last_new_job
# 0          8949  Has relevent experience        >20            1
# 1         29725   No relevent experience         15           >4
# 2         11561   No relevent experience          5        never
# 3         33241   No relevent experience         <1        never
# 4           666  Has relevent experience        >20            4
# 5         21651  Has relevent experience         11            1
# 6         28806  Has relevent experience          5            1
# 7           402  Has relevent experience         13           >4
# 8         27107  Has relevent experience          7            1
# 9           699  Has relevent experience         17           >4
# 10        29452   No relevent experience          2        never
# 11        23853  Has relevent experience          5            1
# 12        25619  Has relevent experience        >20            3
# 13         5826   No relevent experience          2        never
# 14         8722   No relevent experience          5        never
# 15         6588  Has relevent experience         16           >4
# 16         4167  Has relevent experience          1        never
# 17         5764  Has relevent experience          2            2
# 18         2156  Has relevent experience          7        never
# 19        11399  Has relevent experience          4            1
# 20        31972  Has relevent experience         11            1
# 21        19061  Has relevent experience         11            2
# 22         6491  Has relevent experience         10            1
# 23         7041  Has relevent experience         <1            1
# 24        22767  Has relevent experience          5            1
# 25        14505   No relevent experience          4        never
# 26        17139  Has relevent experience         14            1
# 27        28476  Has relevent experience          5            2
# 28        21538  Has relevent experience         11            1
# 29        10408  Has relevent experience         18            2
# 30        14928  Has relevent experience        >20            3
# 31        22293  Has relevent experience         19           >4
# 32         4324   No relevent experience          5            1

# %% [markdown]
# ### 4.Using the 'squeeze' parameter
#
# `squeeze()`: converts a single column DataFrame into a Series.
#
# Note: Squeeze will try to reduce the dimension if its possible to reduce.

# %%
# Read 'new_employee.csv' and squeeze the result into a pandas Series
pd.read_csv("new_employee.csv", usecols=["target"], squeeze= True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_23660\3956872986.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv("new_employee.csv", usecols=["target"], squeeze= True)
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0
# 5     1.0
# 6     0.0
# 7     1.0
# 8     1.0
# 9     0.0
# 10    1.0
# 11    0.0
# 12    0.0
# 13    0.0
# 14    0.0
# 15    0.0
# 16    0.0
# 17    0.0
# 18    1.0
# 19    1.0
# 20    0.0
# 21    0.0
# 22    0.0
# 23    0.0
# 24    0.0
# 25    0.0
# 26    1.0
# 27    0.0
# 28    1.0
# 29    1.0
# 30    0.0
# 31    0.0
# 32    0.0
# Name: target, dtype: float64

# %% [markdown]
# ### 5.Using the 'skiprows' parameter
#
# `skiprows`: Allows skipping a specified number of rows from the beginning of the file.

# %%
# Define a lambda function to get indices of rows to skip
skip_condition = lambda x: x % 2 != 0

# Read 'new_employee.csv' and skiprows of the dataset 
pd.read_csv("new_employee.csv", skiprows=skip_condition)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0         29725   city_40                   0.776    Male
# 1         33241  city_115                   0.789     NaN
# 2         21651  city_176                   0.764     NaN
# 3           402   city_46                   0.762    Male
# 4           699  city_103                   0.920     NaN
# 5         23853  city_103                   0.920    Male
# 6          5826   city_21                   0.624    Male
# 7          6588  city_114                   0.926    Male
# 8          5764   city_21                   0.624     NaN
# 9         11399   city_13                   0.827  Female
# 10        19061  city_114                   0.926    Male
# 11         7041   city_40                   0.776    Male
# 12        14505   city_67                   0.855     NaN
# 13        28476  city_103                   0.920    Male
# 14        10408   city_21                   0.624    Male
# 15        22293  city_103                   0.920    Male
#
#         relevent_experience enrolled_university education_level  \
# 0    No relevent experience       no_enrollment        Graduate
# 1    No relevent experience                 NaN        Graduate
# 2   Has relevent experience    Part time course        Graduate
# 3   Has relevent experience       no_enrollment        Graduate
# 4   Has relevent experience       no_enrollment        Graduate
# 5   Has relevent experience       no_enrollment        Graduate
# 6    No relevent experience                 NaN             NaN
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9   Has relevent experience       no_enrollment        Graduate
# 10  Has relevent experience       no_enrollment         Masters
# 11  Has relevent experience       no_enrollment        Graduate
# 12   No relevent experience       no_enrollment     High School
# 13  Has relevent experience       no_enrollment        Graduate
# 14  Has relevent experience       no_enrollment        Graduate
# 15  Has relevent experience    Part time course        Graduate
#
#    major_discipline experience company_size    company_type last_new_job  \
# 0              STEM         15        50-99         Pvt Ltd           >4
# 1   Business Degree         <1          NaN         Pvt Ltd        never
# 2              STEM         11          NaN             NaN            1
# 3              STEM         13          <10         Pvt Ltd           >4
# 4              STEM         17       10000+         Pvt Ltd           >4
# 5              STEM          5    5000-9999         Pvt Ltd            1
# 6               NaN          2          NaN             NaN        never
# 7              STEM         16        10/49         Pvt Ltd           >4
# 8              STEM          2    5000-9999         Pvt Ltd            2
# 9              Arts          4          NaN             NaN            1
# 10             STEM         11      100-500         Pvt Ltd            2
# 11       Humanities         <1    1000-4999         Pvt Ltd            1
# 12              NaN          4          NaN             NaN        never
# 13             Arts          5          NaN             NaN            2
# 14             STEM         18        50-99  Funded Startup            2
# 15             STEM         19    5000-9999         Pvt Ltd           >4
#
#     training_hours  target
# 0               47     0.0
# 1               52     1.0
# 2               24     1.0
# 3               18     1.0
# 4              123     0.0
# 5              108     0.0
# 6               24     0.0
# 7               18     0.0
# 8                7     0.0
# 9              132     1.0
# 10              50     0.0
# 11              65     0.0
# 12              22     0.0
# 13              72     0.0
# 14              68     1.0
# 15             141     0.0

# %% [markdown]
# ### 6. Using the 'dtype' parameter
#
# `dtype`: Provides a dictionary mapping column names to data types to force the conversion of specific columns.

# %%
# Read 'new_employee.csv' and specify the data type of the 'target' column as integer
pd.read_csv("new_employee.csv", dtype={'target': int})
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# 15         6588  city_114                   0.926    Male
# 16         4167  city_103                   0.920     NaN
# 17         5764   city_21                   0.624     NaN
# 18         2156   city_21                   0.624     NaN
# 19        11399   city_13                   0.827  Female
# 20        31972  city_159                   0.843    Male
# 21        19061  city_114                   0.926    Male
# 22         6491  city_102                   0.804     NaN
# 23         7041   city_40                   0.776    Male
# 24        22767   city_21                   0.624     NaN
# 25        14505   city_67                   0.855     NaN
# 26        17139   city_21                   0.624     NaN
# 27        28476  city_103                   0.920    Male
# 28        21538  city_100                   0.887    Male
# 29        10408   city_21                   0.624    Male
# 30        14928  city_103                   0.920    Male
# 31        22293  city_103                   0.920    Male
# 32         4324  city_103                   0.920  Female
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience                 NaN        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9   Has relevent experience       no_enrollment        Graduate
# 10   No relevent experience    Full time course     High School
# 11  Has relevent experience       no_enrollment        Graduate
# 12  Has relevent experience       no_enrollment        Graduate
# 13   No relevent experience                 NaN             NaN
# 14   No relevent experience    Full time course     High School
# 15  Has relevent experience       no_enrollment        Graduate
# 16  Has relevent experience       no_enrollment        Graduate
# 17  Has relevent experience       no_enrollment        Graduate
# 18  Has relevent experience       no_enrollment        Graduate
# 19  Has relevent experience       no_enrollment        Graduate
# 20  Has relevent experience       no_enrollment         Masters
# 21  Has relevent experience       no_enrollment         Masters
# 22  Has relevent experience       no_enrollment         Masters
# 23  Has relevent experience       no_enrollment        Graduate
# 24  Has relevent experience       no_enrollment        Graduate
# 25   No relevent experience       no_enrollment     High School
# 26  Has relevent experience    Part time course        Graduate
# 27  Has relevent experience       no_enrollment        Graduate
# 28  Has relevent experience       no_enrollment     High School
# 29  Has relevent experience       no_enrollment        Graduate
# 30  Has relevent experience       no_enrollment        Graduate
# 31  Has relevent experience    Part time course        Graduate
# 32   No relevent experience    Full time course        Graduate
#
#    major_discipline experience company_size    company_type last_new_job  \
# 0              STEM        >20          NaN             NaN            1
# 1              STEM         15        50-99         Pvt Ltd           >4
# 2              STEM          5          NaN             NaN        never
# 3   Business Degree         <1          NaN         Pvt Ltd        never
# 4              STEM        >20        50-99  Funded Startup            4
# 5              STEM         11          NaN             NaN            1
# 6               NaN          5        50-99  Funded Startup            1
# 7              STEM         13          <10         Pvt Ltd           >4
# 8              STEM          7        50-99         Pvt Ltd            1
# 9              STEM         17       10000+         Pvt Ltd           >4
# 10              NaN          2          NaN             NaN        never
# 11             STEM          5    5000-9999         Pvt Ltd            1
# 12             STEM        >20    1000-4999         Pvt Ltd            3
# 13              NaN          2          NaN             NaN        never
# 14              NaN          5          NaN             NaN        never
# 15             STEM         16        10/49         Pvt Ltd           >4
# 16             STEM          1        50-99         Pvt Ltd        never
# 17             STEM          2    5000-9999         Pvt Ltd            2
# 18             STEM          7       10000+         Pvt Ltd        never
# 19             Arts          4          NaN             NaN            1
# 20             STEM         11      100-500         Pvt Ltd            1
# 21             STEM         11      100-500         Pvt Ltd            2
# 22             STEM         10          NaN             NaN            1
# 23       Humanities         <1    1000-4999         Pvt Ltd            1
# 24             STEM          5    1000-4999         Pvt Ltd            1
# 25              NaN          4          NaN             NaN        never
# 26             STEM         14      500-999         Pvt Ltd            1
# 27             Arts          5          NaN             NaN            2
# 28              NaN         11          <10         Pvt Ltd            1
# 29             STEM         18        50-99  Funded Startup            2
# 30             STEM        >20      100-500         Pvt Ltd            3
# 31             STEM         19    5000-9999         Pvt Ltd           >4
# 32             STEM          5          NaN             NaN            1
#
#     training_hours  target
# 0               36       1
# 1               47       0
# 2               83       0
# 3               52       1
# 4                8       0
# 5               24       1
# 6               24       0
# 7               18       1
# 8               46       1
# 9              123       0
# 10              32       1
# 11             108       0
# 12              23       0
# 13              24       0
# 14              26       0
# 15              18       0
# 16             106       0
# 17               7       0
# 18              23       1
# 19             132       1
# 20              68       0
# 21              50       0
# 22              48       0
# 23              65       0
# 24              13       0
# 25              22       0
# 26             148       1
# 27              72       0
# 28               8       1
# 29              68       1
# 30              40       0
# 31             141       0
# 32              24       0

# %% [markdown]
# ### 7. Using the 'nrows' parameter
#
# `nrows`: Specifies the maximum number of rows /to read the first n rows of a CSV file.
#
# Note: That the nrows parameter does not affect the total number of rows in the CSV file.

# %%
# Read the first 10 rows of 'new_employee.csv'
pd.read_csv("new_employee.csv", nrows=10)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
# 5        21651  city_176                   0.764    NaN
# 6        28806  city_160                   0.920   Male
# 7          402   city_46                   0.762   Male
# 8        27107  city_103                   0.920   Male
# 9          699  city_103                   0.920    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
# 5  Has relevent experience    Part time course        Graduate
# 6  Has relevent experience       no_enrollment     High School
# 7  Has relevent experience       no_enrollment        Graduate
# 8  Has relevent experience       no_enrollment        Graduate
# 9  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
# 5             STEM         11          NaN             NaN            1
# 6              NaN          5        50-99  Funded Startup            1
# 7             STEM         13          <10         Pvt Ltd           >4
# 8             STEM          7        50-99         Pvt Ltd            1
# 9             STEM         17       10000+         Pvt Ltd           >4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0
# 3              52     1.0
# 4               8     0.0
# 5              24     1.0
# 6              24     0.0
# 7              18     1.0
# 8              46     1.0
# 9             123     0.0

# %% [markdown]
# ### 8. Using the 'na_values' parameter
#
# `na_values`: Additional strings to recognize as NA/NaN. If dict passed, specific per-column NA values. By default the following values are interpreted as NaN

# %%
# The `na_values` parameter is used to specify a list of values that should be treated as missing or NaN (Not a Number) values in the resulting DataFrame. 
# In this case, the value "-" is specified as a missing value indicator.
pd.read_csv("new_employee.csv", na_values=["-"])

# Check row 14
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# 15         6588  city_114                   0.926    Male
# 16         4167  city_103                   0.920     NaN
# 17         5764   city_21                   0.624     NaN
# 18         2156   city_21                   0.624     NaN
# 19        11399   city_13                   0.827  Female
# 20        31972  city_159                   0.843    Male
# 21        19061  city_114                   0.926    Male
# 22         6491  city_102                   0.804     NaN
# 23         7041   city_40                   0.776    Male
# 24        22767   city_21                   0.624     NaN
# 25        14505   city_67                   0.855     NaN
# 26        17139   city_21                   0.624     NaN
# 27        28476  city_103                   0.920    Male
# 28        21538  city_100                   0.887    Male
# 29        10408   city_21                   0.624    Male
# 30        14928  city_103                   0.920    Male
# 31        22293  city_103                   0.920    Male
# 32         4324  city_103                   0.920  Female
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience                 NaN        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9   Has relevent experience       no_enrollment        Graduate
# 10   No relevent experience    Full time course     High School
# 11  Has relevent experience       no_enrollment        Graduate
# 12  Has relevent experience       no_enrollment        Graduate
# 13   No relevent experience                 NaN             NaN
# 14   No relevent experience    Full time course     High School
# 15  Has relevent experience       no_enrollment        Graduate
# 16  Has relevent experience                 NaN        Graduate
# 17  Has relevent experience       no_enrollment        Graduate
# 18  Has relevent experience       no_enrollment        Graduate
# 19  Has relevent experience       no_enrollment        Graduate
# 20  Has relevent experience       no_enrollment         Masters
# 21  Has relevent experience       no_enrollment         Masters
# 22  Has relevent experience       no_enrollment         Masters
# 23  Has relevent experience       no_enrollment        Graduate
# 24  Has relevent experience       no_enrollment        Graduate
# 25   No relevent experience       no_enrollment     High School
# 26  Has relevent experience    Part time course        Graduate
# 27  Has relevent experience       no_enrollment        Graduate
# 28  Has relevent experience       no_enrollment     High School
# 29  Has relevent experience       no_enrollment        Graduate
# 30  Has relevent experience       no_enrollment        Graduate
# 31  Has relevent experience    Part time course        Graduate
# 32   No relevent experience    Full time course        Graduate
#
#    major_discipline experience company_size    company_type last_new_job  \
# 0              STEM        >20          NaN             NaN            1
# 1              STEM         15        50-99         Pvt Ltd           >4
# 2              STEM          5          NaN             NaN        never
# 3   Business Degree         <1          NaN         Pvt Ltd        never
# 4              STEM        >20        50-99  Funded Startup            4
# 5              STEM         11          NaN             NaN            1
# 6               NaN          5        50-99  Funded Startup            1
# 7              STEM         13          <10         Pvt Ltd           >4
# 8              STEM          7        50-99         Pvt Ltd            1
# 9              STEM         17       10000+         Pvt Ltd           >4
# 10              NaN          2          NaN             NaN        never
# 11             STEM          5    5000-9999         Pvt Ltd            1
# 12             STEM        >20    1000-4999         Pvt Ltd            3
# 13              NaN          2          NaN             NaN        never
# 14              NaN          5          NaN             NaN        never
# 15             STEM         16        10/49         Pvt Ltd           >4
# 16             STEM          1        50-99         Pvt Ltd        never
# 17             STEM          2    5000-9999         Pvt Ltd            2
# 18             STEM          7       10000+         Pvt Ltd        never
# 19             Arts          4          NaN             NaN            1
# 20             STEM         11      100-500         Pvt Ltd            1
# 21             STEM         11      100-500         Pvt Ltd            2
# 22             STEM         10          NaN             NaN            1
# 23       Humanities         <1    1000-4999         Pvt Ltd            1
# 24             STEM          5    1000-4999         Pvt Ltd            1
# 25              NaN          4          NaN             NaN        never
# 26             STEM         14      500-999         Pvt Ltd            1
# 27             Arts          5          NaN             NaN            2
# 28              NaN         11          <10         Pvt Ltd            1
# 29             STEM         18        50-99  Funded Startup            2
# 30             STEM        >20      100-500         Pvt Ltd            3
# 31             STEM         19    5000-9999         Pvt Ltd           >4
# 32             STEM          5          NaN             NaN            1
#
#     training_hours  target
# 0               36     1.0
# 1               47     0.0
# 2               83     0.0
# 3               52     1.0
# 4                8     0.0
# 5               24     1.0
# 6               24     0.0
# 7               18     1.0
# 8               46     1.0
# 9              123     0.0
# 10              32     1.0
# 11             108     0.0
# 12              23     0.0
# 13              24     0.0
# 14              26     0.0
# 15              18     0.0
# 16             106     0.0
# 17               7     0.0
# 18              23     1.0
# 19             132     1.0
# 20              68     0.0
# 21              50     0.0
# 22              48     0.0
# 23              65     0.0
# 24              13     0.0
# 25              22     0.0
# 26             148     1.0
# 27              72     0.0
# 28               8     1.0
# 29              68     1.0
# 30              40     0.0
# 31             141     0.0
# 32              24     0.0

# %% [markdown]
# ### 9. Loading a huge dataset in chunks using 'chunksize' parameter
#
# `chunksize`: Number of lines to read from the file per chunk
#
# Note: This parameter determines the number of rows to read at a time while working with large dataset and less memory to load full file at once.
#
# * The maximum size of an individual chunk is 4 TB. The number of allowable chunks is 32,766.

# %%
# The `chunksize=10` parameter specifies that the file should be read in chunks of 10 rows at a time. 
# The resulting object `dfs` is an iterable that contains each chunk of the CSV file.
dfs = pd.read_csv("new_employee.csv",chunksize=10)

# The code is iterating over each chunk of the CSV file and printing the shape of each chunk. 
for chunks in dfs:
    print(chunks.shape)
# Out:
# (10, 14)
# (10, 14)
# (10, 14)
# (3, 14)

# %% [markdown]
# ### 10. Handling Dates using 'parse_dates' parameter
#
# `parse_dates`: A list of columns to be parsed as dates, helping in proper date-time handling.
#
# Note: NaT stands for Not a Time.

# %%
# Read 'new_employee.csv' and parse the 'date' column as datetime
pd.read_csv("new_employee.csv", parse_dates=['year_of_education'])
# Out:
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '15/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '30/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '22/05/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '27/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '18/08/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '21/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '15/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '20/08/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '24/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '13/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '23/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '21/12/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '19/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '14/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '20/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '16/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Users\lenovo\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '26/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# 15         6588  city_114                   0.926    Male
# 16         4167  city_103                   0.920     NaN
# 17         5764   city_21                   0.624     NaN
# 18         2156   city_21                   0.624     NaN
# 19        11399   city_13                   0.827  Female
# 20        31972  city_159                   0.843    Male
# 21        19061  city_114                   0.926    Male
# 22         6491  city_102                   0.804     NaN
# 23         7041   city_40                   0.776    Male
# 24        22767   city_21                   0.624     NaN
# 25        14505   city_67                   0.855     NaN
# 26        17139   city_21                   0.624     NaN
# 27        28476  city_103                   0.920    Male
# 28        21538  city_100                   0.887    Male
# 29        10408   city_21                   0.624    Male
# 30        14928  city_103                   0.920    Male
# 31        22293  city_103                   0.920    Male
# 32         4324  city_103                   0.920  Female
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience                 NaN        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9   Has relevent experience       no_enrollment        Graduate
# 10   No relevent experience    Full time course     High School
# 11  Has relevent experience       no_enrollment        Graduate
# 12  Has relevent experience       no_enrollment        Graduate
# 13   No relevent experience                 NaN             NaN
# 14   No relevent experience    Full time course     High School
# 15  Has relevent experience       no_enrollment        Graduate
# 16  Has relevent experience                   -        Graduate
# 17  Has relevent experience       no_enrollment        Graduate
# 18  Has relevent experience       no_enrollment        Graduate
# 19  Has relevent experience       no_enrollment        Graduate
# 20  Has relevent experience       no_enrollment         Masters
# 21  Has relevent experience       no_enrollment         Masters
# 22  Has relevent experience       no_enrollment         Masters
# 23  Has relevent experience       no_enrollment        Graduate
# 24  Has relevent experience       no_enrollment        Graduate
# 25   No relevent experience       no_enrollment     High School
# 26  Has relevent experience    Part time course        Graduate
# 27  Has relevent experience       no_enrollment        Graduate
# 28  Has relevent experience       no_enrollment     High School
# 29  Has relevent experience       no_enrollment        Graduate
# 30  Has relevent experience       no_enrollment        Graduate
# 31  Has relevent experience    Part time course        Graduate
# 32   No relevent experience    Full time course        Graduate
#
#    year_of_education major_discipline experience company_size    company_type  \
# 0         2020-01-06             STEM        >20          NaN             NaN
# 1         2022-10-15             STEM         15        50-99         Pvt Ltd
# 2         2023-02-02             STEM          5          NaN             NaN
# 3         2022-03-09  Business Degree         <1          NaN         Pvt Ltd
# 4         2021-07-30             STEM        >20        50-99  Funded Startup
# 5         2020-05-22             STEM         11          NaN             NaN
# 6         2021-04-12              NaN          5        50-99  Funded Startup
# 7         2023-03-27             STEM         13          <10         Pvt Ltd
# 8         2020-08-18             STEM          7        50-99         Pvt Ltd
# 9         2021-01-21             STEM         17       10000+         Pvt Ltd
# 10        2022-11-15              NaN          2          NaN             NaN
# 11        2022-09-04             STEM          5    5000-9999         Pvt Ltd
# 12        2023-10-10             STEM        >20    1000-4999         Pvt Ltd
# 13               NaT              NaN          2          NaN           never
# 14               NaT              NaN          5          NaN           never
# 15        2022-05-07             STEM         16        10/49         Pvt Ltd
# 16        2023-07-03             STEM          1        50-99         Pvt Ltd
# 17        2020-08-20             STEM          2    5000-9999         Pvt Ltd
# 18        2021-03-11             STEM          7       10000+         Pvt Ltd
# 19        2022-09-24             Arts          4          NaN             NaN
# 20        2023-02-13             STEM         11      100-500         Pvt Ltd
# 21        2022-05-23             STEM         11      100-500         Pvt Ltd
# 22        2021-01-09             STEM         10          NaN             NaN
# 23        2020-12-21       Humanities         <1    1000-4999         Pvt Ltd
# 24        2022-04-19             STEM          5    1000-4999         Pvt Ltd
# 25        2021-06-08              NaN          4          NaN             NaN
# 26        2023-09-10             STEM         14      500-999         Pvt Ltd
# 27        2022-06-14             Arts          5          NaN             NaN
# 28        2023-03-20              NaN         11          <10         Pvt Ltd
# 29        2022-01-16             STEM         18        50-99  Funded Startup
# 30        2020-03-07             STEM        >20      100-500         Pvt Ltd
# 31        2022-01-12             STEM         19    5000-9999         Pvt Ltd
# 32        2021-04-26             STEM          5          NaN             NaN
#
#    last_new_job  training_hours  target
# 0             1            36.0     1.0
# 1            >4            47.0     0.0
# 2         never            83.0     0.0
# 3         never            52.0     1.0
# 4             4             8.0     0.0
# 5             1            24.0     1.0
# 6             1            24.0     0.0
# 7            >4            18.0     1.0
# 8             1            46.0     1.0
# 9            >4           123.0     0.0
# 10        never            32.0     1.0
# 11            1           108.0     0.0
# 12            3            23.0     0.0
# 13           24             0.0     NaN
# 14           26             0.0     NaN
# 15           >4            18.0     0.0
# 16        never           106.0     0.0
# 17            2             7.0     0.0
# 18        never            23.0     1.0
# 19            1           132.0     1.0
# 20            1            68.0     0.0
# 21            2            50.0     0.0
# 22            1            48.0     0.0
# 23            1            65.0     0.0
# 24            1            13.0     0.0
# 25        never            22.0     0.0
# 26            1           148.0     1.0
# 27            2            72.0     0.0
# 28            1             8.0     1.0
# 29            2            68.0     1.0
# 30            3            40.0     0.0
# 31           >4           141.0     0.0
# 32            1            24.0     0.0

# %% [markdown]
# # Most Important Parameters

# %% [markdown]
# ### 11. Using a Function with 'converters'
#
# `converters`: Functions for converting values in specified columns. Keys can either be column labels or column indices.
#
# Note: dict of {HashableCallable}, optional

# %%
# Define a function to rename a 'major_discipline'
def rename(name):
    if name == "Arts":
        return "Humanities"
    else:
        return name

# Read 'new_employee.csv' and apply the 'rename' function to the 'major_discipline' column
pd.read_csv('new_employee.csv', converters={'major_discipline': rename})
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# 15         6588  city_114                   0.926    Male
# 16         4167  city_103                   0.920     NaN
# 17         5764   city_21                   0.624     NaN
# 18         2156   city_21                   0.624     NaN
# 19        11399   city_13                   0.827  Female
# 20        31972  city_159                   0.843    Male
# 21        19061  city_114                   0.926    Male
# 22         6491  city_102                   0.804     NaN
# 23         7041   city_40                   0.776    Male
# 24        22767   city_21                   0.624     NaN
# 25        14505   city_67                   0.855     NaN
# 26        17139   city_21                   0.624     NaN
# 27        28476  city_103                   0.920    Male
# 28        21538  city_100                   0.887    Male
# 29        10408   city_21                   0.624    Male
# 30        14928  city_103                   0.920    Male
# 31        22293  city_103                   0.920    Male
# 32         4324  city_103                   0.920  Female
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience                 NaN        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9   Has relevent experience       no_enrollment        Graduate
# 10   No relevent experience    Full time course     High School
# 11  Has relevent experience       no_enrollment        Graduate
# 12  Has relevent experience       no_enrollment        Graduate
# 13   No relevent experience                 NaN             NaN
# 14   No relevent experience    Full time course     High School
# 15  Has relevent experience       no_enrollment        Graduate
# 16  Has relevent experience                   -        Graduate
# 17  Has relevent experience       no_enrollment        Graduate
# 18  Has relevent experience       no_enrollment        Graduate
# 19  Has relevent experience       no_enrollment        Graduate
# 20  Has relevent experience       no_enrollment         Masters
# 21  Has relevent experience       no_enrollment         Masters
# 22  Has relevent experience       no_enrollment         Masters
# 23  Has relevent experience       no_enrollment        Graduate
# 24  Has relevent experience       no_enrollment        Graduate
# 25   No relevent experience       no_enrollment     High School
# 26  Has relevent experience    Part time course        Graduate
# 27  Has relevent experience       no_enrollment        Graduate
# 28  Has relevent experience       no_enrollment     High School
# 29  Has relevent experience       no_enrollment        Graduate
# 30  Has relevent experience       no_enrollment        Graduate
# 31  Has relevent experience    Part time course        Graduate
# 32   No relevent experience    Full time course        Graduate
#
#    year_of_education major_discipline experience company_size    company_type  \
# 0         01/06/2020             STEM        >20          NaN             NaN
# 1         15/10/2022             STEM         15        50-99         Pvt Ltd
# 2         02/02/2023             STEM          5          NaN             NaN
# 3         03/09/2022  Business Degree         <1          NaN         Pvt Ltd
# 4         30/07/2021             STEM        >20        50-99  Funded Startup
# 5         22/05/2020             STEM         11          NaN             NaN
# 6         04/12/2021                           5        50-99  Funded Startup
# 7         27/03/2023             STEM         13          <10         Pvt Ltd
# 8         18/08/2020             STEM          7        50-99         Pvt Ltd
# 9         21/01/2021             STEM         17       10000+         Pvt Ltd
# 10        15/11/2022                           2          NaN             NaN
# 11        09/04/2022             STEM          5    5000-9999         Pvt Ltd
# 12        10/10/2023             STEM        >20    1000-4999         Pvt Ltd
# 13               NaN                           2          NaN           never
# 14               NaN                           5          NaN           never
# 15        05/07/2022             STEM         16        10/49         Pvt Ltd
# 16        07/03/2023             STEM          1        50-99         Pvt Ltd
# 17        20/08/2020             STEM          2    5000-9999         Pvt Ltd
# 18        03/11/2021             STEM          7       10000+         Pvt Ltd
# 19        24/09/2022       Humanities          4          NaN             NaN
# 20        13/02/2023             STEM         11      100-500         Pvt Ltd
# 21        23/05/2022             STEM         11      100-500         Pvt Ltd
# 22        01/09/2021             STEM         10          NaN             NaN
# 23        21/12/2020       Humanities         <1    1000-4999         Pvt Ltd
# 24        19/04/2022             STEM          5    1000-4999         Pvt Ltd
# 25        06/08/2021                           4          NaN             NaN
# 26        09/10/2023             STEM         14      500-999         Pvt Ltd
# 27        14/06/2022       Humanities          5          NaN             NaN
# 28        20/03/2023                          11          <10         Pvt Ltd
# 29        16/01/2022             STEM         18        50-99  Funded Startup
# 30        03/07/2020             STEM        >20      100-500         Pvt Ltd
# 31        01/12/2022             STEM         19    5000-9999         Pvt Ltd
# 32        26/04/2021             STEM          5          NaN             NaN
#
#    last_new_job  training_hours  target
# 0             1            36.0     1.0
# 1            >4            47.0     0.0
# 2         never            83.0     0.0
# 3         never            52.0     1.0
# 4             4             8.0     0.0
# 5             1            24.0     1.0
# 6             1            24.0     0.0
# 7            >4            18.0     1.0
# 8             1            46.0     1.0
# 9            >4           123.0     0.0
# 10        never            32.0     1.0
# 11            1           108.0     0.0
# 12            3            23.0     0.0
# 13           24             0.0     NaN
# 14           26             0.0     NaN
# 15           >4            18.0     0.0
# 16        never           106.0     0.0
# 17            2             7.0     0.0
# 18        never            23.0     1.0
# 19            1           132.0     1.0
# 20            1            68.0     0.0
# 21            2            50.0     0.0
# 22            1            48.0     0.0
# 23            1            65.0     0.0
# 24            1            13.0     0.0
# 25        never            22.0     0.0
# 26            1           148.0     1.0
# 27            2            72.0     0.0
# 28            1             8.0     1.0
# 29            2            68.0     1.0
# 30            3            40.0     0.0
# 31           >4           141.0     0.0
# 32            1            24.0     0.0

# %% [markdown]
# ### 12. Opening a 'csv' file from an 'URL'

# %%
# Import necessary libraries
import requests
from io import StringIO

# URL of the CSV file
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
# Set headers to mimic a web browser request
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}
# Make a request to the URL
request = requests.get(url, headers=headers)
# Use StringIO to create a file-like object from the text content of the request
data = StringIO(request.text)

# Read the CSV file from the URL into a pandas DataFrame
pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ### 13. Using the 'delimiter' and 'sep' parameter and naming the columns using 'names'
#
# `delimiter`: Specifies the delimiter used in the file, either a comma (,) for CSV or a tab (\t) for TSV.

# %%
pd.read_csv("occupation_data.tsv", delimiter="\t", names=["movie_name", 'release_year', 'rating', 'votes', 'genres'] )
# Out:
#                     movie_name  release_year  rating   votes  \
# m0  10 things i hate about you          1999     6.9   62847
# m1  1492: conquest of paradise          1992     6.2   10421
# m2                  15 minutes          2001     6.1   25854
# m3       2001: a space odyssey          1968     8.4  163227
# m4                     48 hrs.          1982     6.9   22289
# m5           the fifth element          1997     7.5  133756
# m6                         8mm          1999     6.3   48212
#
#                                                genres
# m0                               ['comedy' 'romance']
# m1        ['adventure' 'biography' 'drama' 'history']
# m2              ['action' 'crime' 'drama' 'thriller']
# m3                   ['adventure' 'mystery' 'sci-fi']
# m4     ['action' 'comedy' 'crime' 'drama' 'thriller']
# m5  ['action' 'adventure' 'romance' 'sci-fi' 'thri...
# m6                     ['crime' 'mystery' 'thriller']

# %% [markdown]
# `sep`: Character or regex pattern to treat as the delimiter, default ‘,’
#
# `names`: Sequence of column labels to apply.
#
# Note: If the file contains a header row, then you should explicitly pass header=0 to override the column names. Duplicates in this list are not allowed.

# %%
pd.read_csv("occupation_data.tsv", sep="\t", names=["movie_name", 'release_year', 'rating', 'votes', 'genres'] )
# Out:
#                     movie_name  release_year  rating   votes  \
# m0  10 things i hate about you          1999     6.9   62847
# m1  1492: conquest of paradise          1992     6.2   10421
# m2                  15 minutes          2001     6.1   25854
# m3       2001: a space odyssey          1968     8.4  163227
# m4                     48 hrs.          1982     6.9   22289
# m5           the fifth element          1997     7.5  133756
# m6                         8mm          1999     6.3   48212
#
#                                                genres
# m0                               ['comedy' 'romance']
# m1        ['adventure' 'biography' 'drama' 'history']
# m2              ['action' 'crime' 'drama' 'thriller']
# m3                   ['adventure' 'mystery' 'sci-fi']
# m4     ['action' 'comedy' 'crime' 'drama' 'thriller']
# m5  ['action' 'adventure' 'romance' 'sci-fi' 'thri...
# m6                     ['crime' 'mystery' 'thriller']

# %% [markdown]
# ### 14. Using the 'header' parameter
#
# `header`: Indicates whether the file has a header row. If set to True, the first row is treated as column headers.

# %%
pd.read_csv("new_employee_test.csv", header= 0)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1         8949  city_103                   0.920   Male
# 1  2        29725   city_40                   0.776   Male
# 2  3        11561   city_21                   0.624    NaN
# 3  4        33241  city_115                   0.789    NaN
# 4  5          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   year_of_education major_discipline experience company_size    company_type  \
# 0        01/06/2020             STEM        >20          NaN             NaN
# 1        15/10/2022             STEM         15        50-99         Pvt Ltd
# 2        02/02/2023             STEM          5          NaN             NaN
# 3        03/09/2022  Business Degree         <1          NaN         Pvt Ltd
# 4        30/07/2021             STEM        >20        50-99  Funded Startup
#
#   last_new_job  training_hours  target
# 0            1              36     1.0
# 1           >4              47     0.0
# 2        never              83     0.0
# 3        never              52     1.0
# 4            4               8     0.0

# %% [markdown]
# ### 15. Using the 'encoding' parameter or 'UnicodeDecodeError' i.e. No 'UTF-8' Encoding
#
# `encoding`: Defines the character encoding of the file, ensuring proper reading of text.
#
# Note: Use 'encoding' when you get some other dataset rather than utf-8 encoded. Example: Emoji's Dataset

# %%
pd.read_csv('people_data.csv',encoding='latin-1')
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   22         London
# 3    Diana   35          Paris
# 4      Eva   28         Berlin

# %% [markdown]
# ### 16. Using the 'error_bad_lines' parameter to handle/skip bad lines or 'ParserError'
#
# `error_bad_lines` : boolean, default True
#
# Lines with too many fields (e.g. a csv line with too many commas) will by default cause an exception to be raised, and no DataFrame will be returned. If False, then these “bad lines” will dropped from the DataFrame that is returned. (Only valid with C parser)

# %%
pd.read_csv('book_data.csv', sep=';', encoding="latin-1",error_bad_lines=False)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_23660\3541247329.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv('book_data.csv', sep=';', encoding="latin-1",error_bad_lines=False)
# b'Skipping line 4: expected 5 fields, saw 6\n'
#                     Title               Author    Genre  Price  \
# 0        The Great Gatsby  F. Scott Fitzgerald  Fiction  10.99
# 1   To Kill a Mockingbird           Harper Lee  Fiction  12.99
# 2     Pride and Prejudice          Jane Austen  Romance   8.99
# 3  The Catcher in the Rye        J.D. Salinger  Fiction  11.99
#
#    Publication_Year
# 0              1925
# 1              1960
# 2              1813
# 3              1951

# %% [markdown]
# These are the major problems I encounter when working with `csv_file`.
#
# For a comprehensive understanding of the `read_csv` function, refer to the official pandas documentation: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html for full scope.
